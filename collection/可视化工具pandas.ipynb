# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
plt.style.use('fast')#设置绘图风格

# https://mp.weixin.qq.com/s/4uuSMWRgZBX997TQ0BS4MQ

# %% [markdown]
# # 1、单组折线图

# %%
np.random.seed(0)#使得每次生成的随机数相同
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts1 = ts.cumsum()#累加
ts1
# Out:
# 2000-01-01     1.764052
# 2000-01-02     2.164210
# 2000-01-03     3.142948
# 2000-01-04     5.383841
# 2000-01-05     7.251399
#                 ...
# 2002-09-22   -43.646776
# 2002-09-23   -43.845175
# 2002-09-24   -43.750982
# 2002-09-25   -44.898593
# 2002-09-26   -45.256707
# Freq: D, Length: 1000, dtype: float64

# %%
ts1.plot(kind="line")#默认绘制折线图
# plt.close()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2、多组折线图

# %%
np.random.seed(0)
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df.plot()  # 默认绘制折线图
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3、单组条形图

# %%
df.iloc[5]
# Out:
# A    3.230518
# B    0.403613
# C    3.694237
# D    2.281223
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4、多组条形图

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5、堆积条形图

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6、水平堆积条形图

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7、直方图

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)
df4.plot.hist(alpha=0.8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # 8、分面直方图

# %%
df
# Out:
#                     A         B          C          D
# 2000-01-01   1.764052  0.400157   0.978738   2.240893
# 2000-01-02   3.631610 -0.577121   1.928826   2.089536
# 2000-01-03   3.528391 -0.166522   2.072870   3.543809
# 2000-01-04   4.289429 -0.044847   2.516733   3.877484
# 2000-01-05   5.783508 -0.250005   2.829801   3.023388
# ...               ...       ...        ...        ...
# 2002-09-22 -66.863909 -1.347448 -26.457709  -9.217353
# 2002-09-23 -64.917859 -0.371066 -26.280551 -10.240526
# 2002-09-24 -64.811139 -1.282947 -27.748918  -9.664047
# 2002-09-25 -64.745833 -2.056460 -27.353970 -10.167937
# 2002-09-26 -62.966274 -2.087032 -25.776882 -10.980739
#
# [1000 rows x 4 columns]

# %%
df.diff().hist(color="#F38181", alpha=0.9, bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'A'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'C'}>,
#         <AxesSubplot:title={'center':'D'}>]], dtype=object)

# %% [markdown]
# # 9、箱图

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df.plot.box(color={"boxes": "#F38181", "whiskers": "#FCE38A", "medians": "#95E1D3", "caps": "black"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 10、面积图

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.plot.area(color=["#F38181", "#FCE38A", "#95E1D3", "#EAFFD0"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 11、堆积面积图

# %%
df.plot.area(stacked=False, color=["#F38181", "#FCE38A", "#95E1D3", "#EAFFD0"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 12、散点图

# %%
ax = df.plot.scatter(x="a", y="b", color="#F38181", label="Group 1",s=90)
df.plot.scatter(x="c", y="d", color="#FCE38A", label="Group 2", ax=ax,s=90)
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %% [markdown]
# # 13、单组饼图

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
series
# Out:
# a    2.299141
# b    2.736283
# c    1.485874
# d    1.592588
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='series'>

# %% [markdown]
# # 14、多组饼图

# %%
df = pd.DataFrame(
    3 * np.random.rand(4, 2), index=["a", "b", "c", "d"], columns=["x", "y"]
)
df.plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<AxesSubplot:ylabel='x'>, <AxesSubplot:ylabel='y'>], dtype=object)

# %% [markdown]
# # 15、分面图

# %%
import matplotlib as mpl
mpl.rc_file_defaults()
# plt.style.use('fivethirtyeight')
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
df
# Out:
#             a         b         c         d
# 0   -1.727575  0.103080 -1.121801 -0.842582
# 1   -0.206933 -1.235447 -0.656783  0.108324
# 2    0.804438  0.265608 -1.128392 -0.772604
# 3   -0.267803 -0.823873 -0.739759  0.342025
# 4    0.674362  1.077156 -1.156005 -0.398809
# ..        ...       ...       ...       ...
# 995 -0.273587 -1.830244  1.127205 -0.910303
# 996  0.936349  1.704433 -1.440550  0.121353
# 997 -0.743203 -0.394977 -0.621962 -1.027043
# 998  0.398862 -1.203724  0.087965 -1.012325
# 999  2.270343 -0.198652  1.014280 -0.576568
#
# [1000 rows x 4 columns]

# %%
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde")
plt.show()

# %% [markdown]
# # 16、hexbin图

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])
df["b"] = df["b"] + np.arange(1000)
df.plot.hexbin(x="a", y="b", gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# # 17、andrews_curves图

# %%
# from pandas.plotting import andrews_curves
# mpl.rc_file_defaults()
# data = pd.read_csv("iris.data.txt")
# # plt.style.use('dark_background')
# andrews_curves(data, "Name")

# %% [markdown]
# # 18、核密度图

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # 19、parallel_coordinates图

# %%
# from pandas.plotting import parallel_coordinates
# data = pd.read_csv("iris.data.txt")
# plt.figure()
# parallel_coordinates(data, "Name")

# %% [markdown]
# # 23、子图（subplot）

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df.plot(subplots=True, figsize=(6, 4))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df.plot(figsize=(6, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 24、子图任意排列

# %%
df.plot(subplots=True, layout=(2, 2), figsize=(6, 6), sharex=False)
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)
